# %% [markdown]
# Author:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# # YOLO en Tiempo Real: Detección de Objetos
#
# En este cuaderno de Jupyter exploraremos la tarea de la detección de objetos en tiempo real utilizando YOLO (You Only Look Once), una técnica avanzada de visión por computadora.
#
# Aprenderemos a utilizar YOLO para identificar y localizar diversos objetos en imágenes y secuencias de video. Esta habilidad es esencial en una amplia gama de aplicaciones, desde la conducción autónoma hasta la vigilancia de seguridad, y representa uno de los avances más emocionantes en el campo de la inteligencia artificial y la visión por computadora.
#
# A lo largo de este tutorial, explorarás conceptos clave como:
#
# - Detección de objetos en tiempo real.
# - Configuración de modelos YOLO pre-entrenados.
# - Interpretación de resultados de detección.
# - Aplicaciones prácticas de la detección de objetos.

# %% [markdown]
# Utilizaremos el comando `!pip` para instalar dos paquetes de Python: `opencv-python` y `ultralytics`.
#
# - `opencv-python`: Es un paquete para tareas de visión por computador en Python. Proporciona una variedad de funciones para el procesamiento de imágenes y videos, incluyendo detección de objetos, manipulación de imágenes y extracción de características.
#
# - `ultralytics`: Es un paquete construido sobre PyTorch, que se enfoca principalmente en tareas de visión por computadora como detección de objetos y clasificación de imágenes. Proporciona interfaces fáciles de usar para entrenar y evaluar modelos de aprendizaje profundo para estas tareas.
#
# Al ejecutar este comando, estás instalando estos paquetes en tu entorno de Python para que puedas usarlos en tu código.

# %%
# Instalamos las librerías necesarias
# %pip install opencv-python ultralytics
# Out:
# Requirement already satisfied: opencv-python in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: ultralytics in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (8.3.31)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.67.0)
# Requirement already satisfied: psutil in c:\users\wilso\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\wilso\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: setuptools in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (75.5.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\wilso\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wilso\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importamos las siguientes bibliotecas en Python:
#
# 1. `ultralytics`: Esta es una biblioteca que proporciona una interfaz para usar modelos de detección de objetos YOLO (You Only Look Once). Permite entrenar, evaluar y utilizar modelos de detección de objetos de manera eficiente.
#
# 2. `cv2` (OpenCV): Esta es una biblioteca popular para el procesamiento de imágenes y videos en Python. Proporciona una amplia gama de funciones para trabajar con imágenes y videos, incluyendo cargar imágenes, realizar operaciones de procesamiento de imágenes, y mostrar imágenes en una ventana, entre otros.
#
# 3. `math`: Este es un módulo estándar de Python que proporciona funciones matemáticas comunes, como funciones trigonométricas, logarítmicas y aritméticas.

# %%
# Importamos las librerías necesarias
from ultralytics import YOLO
import cv2
import math

# %% [markdown]
# Para este tutorial, usaremos un modelo de YOLO preentrenado en una base de datos que contiene imagenes con sus respectivas cordenadas de cuadros delimitadores y etiquetas por cada objeto. La base de datos con la que el modelo fue preentrenado es COCO de Microsoft.

# %%
# Cargamos el modelo YOLO pre-entrenado en COCO dataset
model = YOLO("yolo11n.pt")

# %%
# Revisamos las clases que puede detectar el modelo
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Definimos una lista de nombres con todas las clases para identificar objetos detectados

              # Aquí se enumeran todas las clases

# %%
import cv2
import math

# Definimos una lista de nombres con todas las clases para identificar objetos detectados
classNames = ["tvmonitor"]  # Aquí se enumeran todas las clases

# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0)  # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Alto de la imagen

# Contador para la detección de monitores
tvmonitor_count = 0

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read()  # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

    # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos las coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convertimos a valores enteros

            # Dibujamos la caja delimitadora en la imagen
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Obtenemos la confianza de la detección
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])
            if cls < len(classNames):
                class_name = classNames[cls]
                if class_name == "tvmonitor":
                    tvmonitor_count += 1
                    print(f"TV Monitor detected {tvmonitor_count} times")

    # Mostrar la imagen con las detecciones
    cv2.imshow("Image", img)

    # Salir del bucle si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura y cerrar las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 clock, 322.9ms
# Confidence ---> 0.93
# TV Monitor detected 1 times
# Confidence ---> 0.68
# Speed: 5.0ms preprocess, 322.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 156.8ms
# Confidence ---> 0.93
# TV Monitor detected 2 times
# Confidence ---> 0.72
# Confidence ---> 0.41
# Speed: 4.0ms preprocess, 156.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bird, 1 tv, 1 clock, 157.7ms
# Confidence ---> 0.93
# TV Monitor detected 3 times
# Confidence ---> 0.81
# Confidence ---> 0.39
# Confidence ---> 0.28
# Speed: 9.0ms preprocess, 157.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 162.7ms
# Confidence ---> 0.92
# TV Monitor detected 4 times
# Confidence ---> 0.73
# Confidence ---> 0.33
# Speed: 3.0ms preprocess, 162.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 170.4ms
# Confidence ---> 0.93
# TV Monitor detected 5 times
# Confidence ---> 0.75
# Confidence ---> 0.27
# Speed: 6.5ms preprocess, 170.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 159.9ms
# Confidence ---> 0.93
# TV Monitor detected 6 times
# Confidence ---> 0.72
# Speed: 4.0ms preprocess, 159.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 135.4ms
# Confidence ---> 0.93
# TV Monitor detected 7 times
# Confidence ---> 0.75
# Confidence ---> 0.31
# Speed: 3.0ms preprocess, 135.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 152.8ms
# Confidence ---> 0.93
# TV Monitor detected 8 times
# Confidence ---> 0.66
# Speed: 6.0ms preprocess, 152.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 146.2ms
# Confidence ---> 0.93
# TV Monitor detected 9 times
# Confidence ---> 0.77
# Confidence ---> 0.36
# Speed: 2.6ms preprocess, 146.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 135.9ms
# Confidence ---> 0.93
# TV Monitor detected 10 times
# Confidence ---> 0.75
# Confidence ---> 0.43
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 135.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 128.0ms
# Confidence ---> 0.93
# TV Monitor detected 11 times
# Confidence ---> 0.75
# Confidence ---> 0.32
# Confidence ---> 0.29
# Speed: 7.0ms preprocess, 128.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 195.2ms
# Confidence ---> 0.92
# TV Monitor detected 12 times
# Confidence ---> 0.78
# Confidence ---> 0.29
# Confidence ---> 0.26
# Speed: 4.0ms preprocess, 195.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 2 clocks, 158.0ms
# Confidence ---> 0.93
# TV Monitor detected 13 times
# Confidence ---> 0.8
# Confidence ---> 0.33
# Confidence ---> 0.31
# Confidence ---> 0.29
# Speed: 7.0ms preprocess, 158.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 153.5ms
# Confidence ---> 0.93
# TV Monitor detected 14 times
# Confidence ---> 0.73
# Confidence ---> 0.41
# Confidence ---> 0.3
# Speed: 0.0ms preprocess, 153.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 198.5ms
# Confidence ---> 0.93
# TV Monitor detected 15 times
# Confidence ---> 0.69
# Confidence ---> 0.35
# Speed: 3.0ms preprocess, 198.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 158.4ms
# Confidence ---> 0.93
# TV Monitor detected 16 times
# Confidence ---> 0.78
# Confidence ---> 0.27
# Speed: 3.0ms preprocess, 158.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 143.5ms
# Confidence ---> 0.93
# TV Monitor detected 17 times
# Confidence ---> 0.76
# Confidence ---> 0.38
# Speed: 3.0ms preprocess, 143.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 139.5ms
# Confidence ---> 0.93
# TV Monitor detected 18 times
# Confidence ---> 0.75
# Confidence ---> 0.42
# Speed: 2.0ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 128.0ms
# Confidence ---> 0.93
# TV Monitor detected 19 times
# Confidence ---> 0.31
# Confidence ---> 0.3
# Confidence ---> 0.3
# Speed: 3.0ms preprocess, 128.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 131.0ms
# Confidence ---> 0.93
# TV Monitor detected 20 times
# Confidence ---> 0.39
# Confidence ---> 0.33
# Confidence ---> 0.32
# Speed: 2.0ms preprocess, 131.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 133.0ms
# Confidence ---> 0.88
# TV Monitor detected 21 times
# Confidence ---> 0.67
# Confidence ---> 0.42
# Confidence ---> 0.3
# Speed: 3.0ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 133.1ms
# Confidence ---> 0.87
# TV Monitor detected 22 times
# Confidence ---> 0.66
# Confidence ---> 0.48
# Confidence ---> 0.42
# Speed: 2.0ms preprocess, 133.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 128.9ms
# Confidence ---> 0.87
# TV Monitor detected 23 times
# Confidence ---> 0.66
# Confidence ---> 0.48
# Confidence ---> 0.35
# Speed: 3.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 127.7ms
# Confidence ---> 0.89
# TV Monitor detected 24 times
# Confidence ---> 0.68
# Confidence ---> 0.51
# Confidence ---> 0.3
# Speed: 2.0ms preprocess, 127.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 128.7ms
# Confidence ---> 0.9
# TV Monitor detected 25 times
# Confidence ---> 0.62
# Confidence ---> 0.4
# Confidence ---> 0.28
# Speed: 2.0ms preprocess, 128.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 124.7ms
# Confidence ---> 0.89
# TV Monitor detected 26 times
# Confidence ---> 0.51
# Confidence ---> 0.45
# Confidence ---> 0.42
# Speed: 2.2ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 145.7ms
# Confidence ---> 0.89
# TV Monitor detected 27 times
# Confidence ---> 0.63
# Confidence ---> 0.5
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 145.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 143.8ms
# Confidence ---> 0.89
# TV Monitor detected 28 times
# Confidence ---> 0.49
# Confidence ---> 0.44
# Confidence ---> 0.35
# Speed: 2.0ms preprocess, 143.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 190.1ms
# Confidence ---> 0.89
# TV Monitor detected 29 times
# Confidence ---> 0.62
# Confidence ---> 0.48
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 190.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 141.9ms
# Confidence ---> 0.93
# TV Monitor detected 30 times
# Confidence ---> 0.56
# Confidence ---> 0.43
# Speed: 3.0ms preprocess, 141.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 139.0ms
# Confidence ---> 0.94
# TV Monitor detected 31 times
# Confidence ---> 0.61
# Confidence ---> 0.54
# Confidence ---> 0.33
# Speed: 3.0ms preprocess, 139.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 125.6ms
# Confidence ---> 0.95
# TV Monitor detected 32 times
# Confidence ---> 0.55
# Confidence ---> 0.4
# Speed: 3.2ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 133.6ms
# Confidence ---> 0.95
# TV Monitor detected 33 times
# Confidence ---> 0.65
# Confidence ---> 0.27
# Speed: 3.0ms preprocess, 133.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 126.1ms
# Confidence ---> 0.95
# TV Monitor detected 34 times
# Confidence ---> 0.7
# Confidence ---> 0.44
# Confidence ---> 0.32
# Speed: 3.0ms preprocess, 126.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 132.8ms
# Confidence ---> 0.96
# TV Monitor detected 35 times
# Confidence ---> 0.51
# Confidence ---> 0.36
# Speed: 4.0ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 139.6ms
# Confidence ---> 0.95
# TV Monitor detected 36 times
# Confidence ---> 0.49
# Confidence ---> 0.36
# Speed: 2.0ms preprocess, 139.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 cell phone, 126.6ms
# Confidence ---> 0.94
# TV Monitor detected 37 times
# Confidence ---> 0.51
# Confidence ---> 0.42
# Confidence ---> 0.36
# Confidence ---> 0.32
# Speed: 3.0ms preprocess, 126.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 127.5ms
# Confidence ---> 0.95
# TV Monitor detected 38 times
# Confidence ---> 0.46
# Confidence ---> 0.41
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 197.5ms
# Confidence ---> 0.94
# TV Monitor detected 39 times
# Confidence ---> 0.43
# Confidence ---> 0.37
# Speed: 4.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 143.5ms
# Confidence ---> 0.94
# TV Monitor detected 40 times
# Confidence ---> 0.79
# Confidence ---> 0.44
# Speed: 3.0ms preprocess, 143.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 138.9ms
# Confidence ---> 0.94
# TV Monitor detected 41 times
# Confidence ---> 0.75
# Confidence ---> 0.26
# Speed: 2.0ms preprocess, 138.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 147.2ms
# Confidence ---> 0.93
# TV Monitor detected 42 times
# Confidence ---> 0.78
# Confidence ---> 0.47
# Confidence ---> 0.27
# Speed: 2.0ms preprocess, 147.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 139.8ms
# Confidence ---> 0.93
# TV Monitor detected 43 times
# Confidence ---> 0.71
# Confidence ---> 0.31
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 139.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 131.1ms
# Confidence ---> 0.93
# TV Monitor detected 44 times
# Confidence ---> 0.77
# Confidence ---> 0.44
# Confidence ---> 0.29
# Speed: 2.0ms preprocess, 131.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 129.6ms
# Confidence ---> 0.93
# TV Monitor detected 45 times
# Confidence ---> 0.73
# Confidence ---> 0.33
# Speed: 3.0ms preprocess, 129.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 130.9ms
# Confidence ---> 0.93
# TV Monitor detected 46 times
# Confidence ---> 0.79
# Confidence ---> 0.42
# Speed: 3.0ms preprocess, 130.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 134.0ms
# Confidence ---> 0.93
# TV Monitor detected 47 times
# Confidence ---> 0.77
# Confidence ---> 0.4
# Speed: 2.0ms preprocess, 134.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 128.6ms
# Confidence ---> 0.93
# TV Monitor detected 48 times
# Confidence ---> 0.73
# Confidence ---> 0.42
# Speed: 3.5ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 127.6ms
# Confidence ---> 0.93
# TV Monitor detected 49 times
# Confidence ---> 0.47
# Confidence ---> 0.37
# Confidence ---> 0.31
# Speed: 3.0ms preprocess, 127.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 cell phone, 131.9ms
# Confidence ---> 0.93
# TV Monitor detected 50 times
# Confidence ---> 0.6
# Confidence ---> 0.45
# Confidence ---> 0.42
# Confidence ---> 0.3
# Speed: 2.0ms preprocess, 131.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 127.9ms
# Confidence ---> 0.95
# TV Monitor detected 51 times
# Confidence ---> 0.35
# Confidence ---> 0.29
# Confidence ---> 0.27
# Speed: 3.0ms preprocess, 127.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 148.4ms
# Confidence ---> 0.91
# TV Monitor detected 52 times
# Confidence ---> 0.72
# Confidence ---> 0.48
# Confidence ---> 0.37
# Speed: 3.0ms preprocess, 148.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 143.2ms
# Confidence ---> 0.92
# TV Monitor detected 53 times
# Confidence ---> 0.62
# Confidence ---> 0.5
# Confidence ---> 0.29
# Speed: 3.0ms preprocess, 143.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 146.6ms
# Confidence ---> 0.94
# TV Monitor detected 54 times
# Confidence ---> 0.56
# Confidence ---> 0.46
# Confidence ---> 0.41
# Speed: 4.0ms preprocess, 146.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 141.7ms
# Confidence ---> 0.96
# TV Monitor detected 55 times
# Confidence ---> 0.56
# Confidence ---> 0.5
# Confidence ---> 0.43
# Speed: 3.0ms preprocess, 141.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 143.8ms
# Confidence ---> 0.95
# TV Monitor detected 56 times
# Confidence ---> 0.57
# Confidence ---> 0.54
# Confidence ---> 0.39
# Speed: 3.0ms preprocess, 143.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 140.7ms
# Confidence ---> 0.95
# TV Monitor detected 57 times
# Confidence ---> 0.48
# Confidence ---> 0.43
# Confidence ---> 0.42
# Speed: 3.0ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 cell phone, 165.2ms
# Confidence ---> 0.94
# TV Monitor detected 58 times
# Confidence ---> 0.47
# Confidence ---> 0.36
# Speed: 4.0ms preprocess, 165.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 192.5ms
# Confidence ---> 0.94
# TV Monitor detected 59 times
# Confidence ---> 0.55
# Confidence ---> 0.45
# Confidence ---> 0.39
# Speed: 3.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 183.6ms
# Confidence ---> 0.93
# TV Monitor detected 60 times
# Confidence ---> 0.52
# Confidence ---> 0.26
# Speed: 3.0ms preprocess, 183.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 159.1ms
# Confidence ---> 0.93
# TV Monitor detected 61 times
# Confidence ---> 0.58
# Confidence ---> 0.51
# Speed: 0.0ms preprocess, 159.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 126.5ms
# Confidence ---> 0.93
# TV Monitor detected 62 times
# Confidence ---> 0.69
# Confidence ---> 0.34
# Confidence ---> 0.26
# Speed: 2.0ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 128.9ms
# Confidence ---> 0.93
# TV Monitor detected 63 times
# Confidence ---> 0.55
# Confidence ---> 0.48
# Speed: 2.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 139.1ms
# Confidence ---> 0.93
# TV Monitor detected 64 times
# Confidence ---> 0.7
# Confidence ---> 0.4
# Speed: 2.0ms preprocess, 139.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 154.7ms
# Confidence ---> 0.95
# TV Monitor detected 65 times
# Confidence ---> 0.55
# Confidence ---> 0.4
# Confidence ---> 0.26
# Speed: 0.0ms preprocess, 154.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 186.9ms
# Confidence ---> 0.94
# TV Monitor detected 66 times
# Confidence ---> 0.5
# Confidence ---> 0.48
# Confidence ---> 0.42
# Speed: 2.4ms preprocess, 186.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 149.7ms
# Confidence ---> 0.95
# TV Monitor detected 67 times
# Confidence ---> 0.84
# Confidence ---> 0.39
# Speed: 3.0ms preprocess, 149.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 139.5ms
# Confidence ---> 0.94
# TV Monitor detected 68 times
# Confidence ---> 0.86
# Confidence ---> 0.4
# Speed: 2.0ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 133.9ms
# Confidence ---> 0.94
# TV Monitor detected 69 times
# Confidence ---> 0.87
# Confidence ---> 0.41
# Speed: 3.2ms preprocess, 133.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 127.4ms
# Confidence ---> 0.95
# TV Monitor detected 70 times
# Confidence ---> 0.82
# Confidence ---> 0.49
# Speed: 3.0ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 131.8ms
# Confidence ---> 0.94
# TV Monitor detected 71 times
# Confidence ---> 0.84
# Confidence ---> 0.44
# Speed: 3.0ms preprocess, 131.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 129.6ms
# Confidence ---> 0.94
# TV Monitor detected 72 times
# Confidence ---> 0.67
# Confidence ---> 0.56
# Confidence ---> 0.37
# Speed: 3.0ms preprocess, 129.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 125.5ms
# Confidence ---> 0.94
# TV Monitor detected 73 times
# Confidence ---> 0.57
# Confidence ---> 0.53
# Speed: 3.1ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 128.0ms
# Confidence ---> 0.95
# TV Monitor detected 74 times
# Confidence ---> 0.63
# Confidence ---> 0.33
# Speed: 3.0ms preprocess, 128.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 132.4ms
# Confidence ---> 0.94
# TV Monitor detected 75 times
# Confidence ---> 0.66
# Confidence ---> 0.43
# Speed: 2.0ms preprocess, 132.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 142.9ms
# Confidence ---> 0.94
# TV Monitor detected 76 times
# Confidence ---> 0.66
# Confidence ---> 0.39
# Speed: 3.0ms preprocess, 142.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 155.4ms
# Confidence ---> 0.93
# TV Monitor detected 77 times
# Confidence ---> 0.74
# Confidence ---> 0.41
# Speed: 2.5ms preprocess, 155.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 152.1ms
# Confidence ---> 0.94
# TV Monitor detected 78 times
# Confidence ---> 0.6
# Confidence ---> 0.58
# Confidence ---> 0.32
# Speed: 3.0ms preprocess, 152.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 186.6ms
# Confidence ---> 0.94
# TV Monitor detected 79 times
# Confidence ---> 0.74
# Confidence ---> 0.42
# Speed: 2.0ms preprocess, 186.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 155.5ms
# Confidence ---> 0.94
# TV Monitor detected 80 times
# Confidence ---> 0.64
# Confidence ---> 0.48
# Confidence ---> 0.3
# Speed: 3.0ms preprocess, 155.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 146.2ms
# Confidence ---> 0.95
# TV Monitor detected 81 times
# Confidence ---> 0.54
# Confidence ---> 0.39
# Speed: 2.0ms preprocess, 146.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 129.4ms
# Confidence ---> 0.94
# TV Monitor detected 82 times
# Confidence ---> 0.61
# Confidence ---> 0.36
# Speed: 3.0ms preprocess, 129.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 144.3ms
# Confidence ---> 0.95
# TV Monitor detected 83 times
# Confidence ---> 0.57
# Confidence ---> 0.42
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 144.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 172.0ms
# Confidence ---> 0.95
# TV Monitor detected 84 times
# Confidence ---> 0.66
# Confidence ---> 0.43
# Speed: 2.5ms preprocess, 172.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 129.0ms
# Confidence ---> 0.95
# TV Monitor detected 85 times
# Confidence ---> 0.62
# Confidence ---> 0.47
# Speed: 2.5ms preprocess, 129.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 133.8ms
# Confidence ---> 0.95
# TV Monitor detected 86 times
# Confidence ---> 0.65
# Confidence ---> 0.45
# Speed: 3.0ms preprocess, 133.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 130.6ms
# Confidence ---> 0.95
# TV Monitor detected 87 times
# Confidence ---> 0.66
# Confidence ---> 0.36
# Speed: 3.0ms preprocess, 130.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 129.0ms
# Confidence ---> 0.94
# TV Monitor detected 88 times
# Confidence ---> 0.63
# Confidence ---> 0.45
# Confidence ---> 0.35
# Speed: 2.0ms preprocess, 129.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 189.7ms
# Confidence ---> 0.95
# TV Monitor detected 89 times
# Confidence ---> 0.58
# Confidence ---> 0.36
# Speed: 3.2ms preprocess, 189.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 139.3ms
# Confidence ---> 0.94
# TV Monitor detected 90 times
# Confidence ---> 0.65
# Confidence ---> 0.42
# Speed: 3.0ms preprocess, 139.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 139.8ms
# Confidence ---> 0.94
# TV Monitor detected 91 times
# Confidence ---> 0.68
# Confidence ---> 0.37
# Speed: 0.0ms preprocess, 139.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 143.7ms
# Confidence ---> 0.94
# TV Monitor detected 92 times
# Confidence ---> 0.55
# Confidence ---> 0.35
# Speed: 0.0ms preprocess, 143.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 150.4ms
# Confidence ---> 0.95
# TV Monitor detected 93 times
# Confidence ---> 0.59
# Confidence ---> 0.46
# Speed: 3.0ms preprocess, 150.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 138.0ms
# Confidence ---> 0.95
# TV Monitor detected 94 times
# Confidence ---> 0.65
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 138.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 132.1ms
# Confidence ---> 0.95
# TV Monitor detected 95 times
# Confidence ---> 0.55
# Speed: 2.0ms preprocess, 132.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 132.6ms
# Confidence ---> 0.95
# TV Monitor detected 96 times
# Confidence ---> 0.59
# Confidence ---> 0.32
# Confidence ---> 0.26
# Speed: 2.0ms preprocess, 132.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 124.4ms
# Confidence ---> 0.95
# TV Monitor detected 97 times
# Confidence ---> 0.53
# Confidence ---> 0.37
# Speed: 2.0ms preprocess, 124.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 126.3ms
# Confidence ---> 0.95
# TV Monitor detected 98 times
# Confidence ---> 0.52
# Confidence ---> 0.35
# Speed: 3.0ms preprocess, 126.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 131.9ms
# Confidence ---> 0.96
# TV Monitor detected 99 times
# Confidence ---> 0.42
# Confidence ---> 0.42
# Confidence ---> 0.27
# Speed: 3.0ms preprocess, 131.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 132.0ms
# Confidence ---> 0.95
# TV Monitor detected 100 times
# Confidence ---> 0.58
# Confidence ---> 0.43
# Confidence ---> 0.26
# Speed: 2.0ms preprocess, 132.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 134.3ms
# Confidence ---> 0.96
# TV Monitor detected 101 times
# Confidence ---> 0.52
# Confidence ---> 0.48
# Confidence ---> 0.28
# Speed: 2.0ms preprocess, 134.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 141.3ms
# Confidence ---> 0.96
# TV Monitor detected 102 times
# Confidence ---> 0.49
# Confidence ---> 0.39
# Speed: 3.0ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 144.6ms
# Confidence ---> 0.96
# TV Monitor detected 103 times
# Confidence ---> 0.54
# Confidence ---> 0.37
# Speed: 2.0ms preprocess, 144.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 141.6ms
# Confidence ---> 0.96
# TV Monitor detected 104 times
# Confidence ---> 0.46
# Confidence ---> 0.44
# Speed: 2.0ms preprocess, 141.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 139.5ms
# Confidence ---> 0.96
# TV Monitor detected 105 times
# Confidence ---> 0.52
# Confidence ---> 0.45
# Speed: 5.0ms preprocess, 139.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 152.8ms
# Confidence ---> 0.95
# TV Monitor detected 106 times
# Confidence ---> 0.6
# Confidence ---> 0.37
# Confidence ---> 0.27
# Speed: 3.0ms preprocess, 152.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 136.1ms
# Confidence ---> 0.95
# TV Monitor detected 107 times
# Confidence ---> 0.45
# Confidence ---> 0.35
# Speed: 3.0ms preprocess, 136.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 126.8ms
# Confidence ---> 0.95
# TV Monitor detected 108 times
# Confidence ---> 0.59
# Confidence ---> 0.35
# Speed: 4.0ms preprocess, 126.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 128.8ms
# Confidence ---> 0.95
# TV Monitor detected 109 times
# Confidence ---> 0.58
# Confidence ---> 0.38
# Speed: 3.0ms preprocess, 128.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 127.5ms
# Confidence ---> 0.95
# TV Monitor detected 110 times
# Confidence ---> 0.59
# Confidence ---> 0.5
# Speed: 2.0ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 126.7ms
# Confidence ---> 0.96
# TV Monitor detected 111 times
# Confidence ---> 0.56
# Confidence ---> 0.45
# Speed: 3.0ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 190.8ms
# Confidence ---> 0.95
# TV Monitor detected 112 times
# Confidence ---> 0.59
# Confidence ---> 0.43
# Confidence ---> 0.28
# Speed: 4.0ms preprocess, 190.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 129.8ms
# Confidence ---> 0.96
# TV Monitor detected 113 times
# Confidence ---> 0.53
# Confidence ---> 0.38
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 129.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 127.4ms
# Confidence ---> 0.96
# TV Monitor detected 114 times
# Confidence ---> 0.64
# Confidence ---> 0.42
# Speed: 2.0ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 142.2ms
# Confidence ---> 0.95
# TV Monitor detected 115 times
# Confidence ---> 0.6
# Confidence ---> 0.48
# Confidence ---> 0.26
# Speed: 4.0ms preprocess, 142.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 137.8ms
# Confidence ---> 0.95
# TV Monitor detected 116 times
# Confidence ---> 0.51
# Confidence ---> 0.5
# Confidence ---> 0.34
# Speed: 3.0ms preprocess, 137.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 143.3ms
# Confidence ---> 0.95
# TV Monitor detected 117 times
# Confidence ---> 0.55
# Speed: 2.0ms preprocess, 143.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 156.3ms
# Confidence ---> 0.95
# TV Monitor detected 118 times
# Confidence ---> 0.59
# Confidence ---> 0.34
# Speed: 3.0ms preprocess, 156.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 146.7ms
# Confidence ---> 0.95
# TV Monitor detected 119 times
# Confidence ---> 0.6
# Confidence ---> 0.3
# Speed: 3.0ms preprocess, 146.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 134.3ms
# Confidence ---> 0.95
# TV Monitor detected 120 times
# Confidence ---> 0.56
# Confidence ---> 0.47
# Speed: 3.0ms preprocess, 134.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 129.5ms
# Confidence ---> 0.95
# TV Monitor detected 121 times
# Confidence ---> 0.5
# Confidence ---> 0.28
# Speed: 2.0ms preprocess, 129.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 132.3ms
# Confidence ---> 0.95
# TV Monitor detected 122 times
# Confidence ---> 0.59
# Confidence ---> 0.37
# Speed: 3.0ms preprocess, 132.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 130.2ms
# Confidence ---> 0.95
# TV Monitor detected 123 times
# Confidence ---> 0.57
# Confidence ---> 0.4
# Speed: 3.0ms preprocess, 130.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 130.8ms
# Confidence ---> 0.94
# TV Monitor detected 124 times
# Confidence ---> 0.63
# Confidence ---> 0.44
# Speed: 3.0ms preprocess, 130.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bird, 1 tv, 130.1ms
# Confidence ---> 0.94
# TV Monitor detected 125 times
# Confidence ---> 0.52
# Confidence ---> 0.43
# Speed: 3.0ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 141.0ms
# Confidence ---> 0.93
# TV Monitor detected 126 times
# Confidence ---> 0.56
# Confidence ---> 0.44
# Confidence ---> 0.29
# Speed: 2.0ms preprocess, 141.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 134.0ms
# Confidence ---> 0.94
# TV Monitor detected 127 times
# Confidence ---> 0.46
# Confidence ---> 0.39
# Speed: 4.0ms preprocess, 134.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 141.0ms
# Confidence ---> 0.92
# TV Monitor detected 128 times
# Confidence ---> 0.6
# Confidence ---> 0.54
# Confidence ---> 0.41
# Speed: 3.0ms preprocess, 141.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 147.1ms
# Confidence ---> 0.94
# TV Monitor detected 129 times
# Confidence ---> 0.59
# Confidence ---> 0.5
# Speed: 3.0ms preprocess, 147.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 145.2ms
# Confidence ---> 0.94
# TV Monitor detected 130 times
# Confidence ---> 0.63
# Speed: 4.0ms preprocess, 145.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 145.2ms
# Confidence ---> 0.94
# TV Monitor detected 131 times
# Confidence ---> 0.52
# Confidence ---> 0.36
# Confidence ---> 0.35
# Speed: 3.0ms preprocess, 145.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 145.0ms
# Confidence ---> 0.92
# TV Monitor detected 132 times
# Confidence ---> 0.5
# Speed: 3.0ms preprocess, 145.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 134.3ms
# Confidence ---> 0.92
# TV Monitor detected 133 times
# Confidence ---> 0.57
# Confidence ---> 0.27
# Speed: 2.0ms preprocess, 134.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 clock, 127.3ms
# Confidence ---> 0.92
# TV Monitor detected 134 times
# Confidence ---> 0.8
# Confidence ---> 0.6
# TV Monitor detected 135 times
# Confidence ---> 0.52
# Speed: 3.0ms preprocess, 127.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 tvs, 1 clock, 188.1ms
# Confidence ---> 0.93
# TV Monitor detected 136 times
# Confidence ---> 0.81
# Confidence ---> 0.67
# TV Monitor detected 137 times
# Confidence ---> 0.48
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 188.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 129.0ms
# Confidence ---> 0.93
# TV Monitor detected 138 times
# Confidence ---> 0.66
# Confidence ---> 0.32
# Speed: 2.0ms preprocess, 129.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 127.0ms
# Confidence ---> 0.93
# TV Monitor detected 139 times
# Confidence ---> 0.65
# Confidence ---> 0.55
# Speed: 4.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 128.5ms
# Confidence ---> 0.92
# TV Monitor detected 140 times
# Confidence ---> 0.69
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 128.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 125.7ms
# Confidence ---> 0.94
# TV Monitor detected 141 times
# Confidence ---> 0.65
# Speed: 4.0ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 126.4ms
# Confidence ---> 0.89
# TV Monitor detected 142 times
# Confidence ---> 0.54
# Speed: 3.0ms preprocess, 126.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 159.0ms
# Confidence ---> 0.9
# TV Monitor detected 143 times
# Confidence ---> 0.69
# Speed: 2.0ms preprocess, 159.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 141.6ms
# Confidence ---> 0.91
# TV Monitor detected 144 times
# Confidence ---> 0.46
# Speed: 2.0ms preprocess, 141.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.5ms
# Confidence ---> 0.93
# TV Monitor detected 145 times
# Speed: 2.5ms preprocess, 146.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 145.9ms
# Confidence ---> 0.93
# TV Monitor detected 146 times
# Speed: 5.6ms preprocess, 145.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.6ms
# Confidence ---> 0.92
# TV Monitor detected 147 times
# Speed: 3.0ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 clock, 133.5ms
# Confidence ---> 0.91
# TV Monitor detected 148 times
# Confidence ---> 0.74
# TV Monitor detected 149 times
# Confidence ---> 0.49
# Speed: 3.0ms preprocess, 133.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 tvs, 1 clock, 141.7ms
# Confidence ---> 0.91
# TV Monitor detected 150 times
# Confidence ---> 0.72
# Confidence ---> 0.7
# TV Monitor detected 151 times
# Confidence ---> 0.46
# Confidence ---> 0.26
# Speed: 3.0ms preprocess, 141.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 clock, 132.0ms
# Confidence ---> 0.92
# TV Monitor detected 152 times
# Confidence ---> 0.64
# Confidence ---> 0.53
# TV Monitor detected 153 times
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 135.2ms
# Confidence ---> 0.91
# TV Monitor detected 154 times
# Confidence ---> 0.57
# Confidence ---> 0.26
# Speed: 2.0ms preprocess, 135.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 130.5ms
# Confidence ---> 0.92
# TV Monitor detected 155 times
# Confidence ---> 0.63
# Speed: 3.0ms preprocess, 130.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 potted plant, 1 tv, 1 clock, 127.8ms
# Confidence ---> 0.93
# TV Monitor detected 156 times
# Confidence ---> 0.75
# Confidence ---> 0.3
# Confidence ---> 0.28
# Speed: 2.0ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 126.1ms
# Confidence ---> 0.93
# TV Monitor detected 157 times
# Confidence ---> 0.61
# Speed: 2.0ms preprocess, 126.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 128.9ms
# Confidence ---> 0.92
# TV Monitor detected 158 times
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 147.6ms
# Confidence ---> 0.93
# TV Monitor detected 159 times
# Confidence ---> 0.35
# Speed: 3.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 185.6ms
# Confidence ---> 0.93
# TV Monitor detected 160 times
# Confidence ---> 0.31
# Speed: 4.0ms preprocess, 185.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 148.6ms
# Confidence ---> 0.95
# TV Monitor detected 161 times
# Confidence ---> 0.49
# Confidence ---> 0.47
# Speed: 3.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 142.2ms
# Confidence ---> 0.94
# TV Monitor detected 162 times
# Confidence ---> 0.39
# Confidence ---> 0.27
# Speed: 4.0ms preprocess, 142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 202.9ms
# Confidence ---> 0.95
# TV Monitor detected 163 times
# Confidence ---> 0.35
# Confidence ---> 0.27
# Speed: 3.0ms preprocess, 202.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 141.4ms
# Confidence ---> 0.94
# TV Monitor detected 164 times
# Confidence ---> 0.43
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 microwave, 1 clock, 127.9ms
# Confidence ---> 0.94
# TV Monitor detected 165 times
# Confidence ---> 0.42
# Confidence ---> 0.39
# Speed: 2.0ms preprocess, 127.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 microwaves, 1 clock, 129.2ms
# Confidence ---> 0.93
# TV Monitor detected 166 times
# Confidence ---> 0.52
# Confidence ---> 0.44
# Confidence ---> 0.33
# Speed: 2.0ms preprocess, 129.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 microwave, 1 clock, 130.8ms
# Confidence ---> 0.92
# TV Monitor detected 167 times
# Confidence ---> 0.66
# Confidence ---> 0.53
# Speed: 3.0ms preprocess, 130.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 microwave, 1 clock, 128.7ms
# Confidence ---> 0.92
# TV Monitor detected 168 times
# Confidence ---> 0.59
# Confidence ---> 0.37
# Confidence ---> 0.32
# Speed: 3.0ms preprocess, 128.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 microwave, 1 clock, 131.9ms
# Confidence ---> 0.92
# TV Monitor detected 169 times
# Confidence ---> 0.5
# Confidence ---> 0.4
# Speed: 3.0ms preprocess, 131.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 microwave, 1 clock, 121.2ms
# Confidence ---> 0.92
# TV Monitor detected 170 times
# Confidence ---> 0.63
# Confidence ---> 0.43
# Speed: 3.0ms preprocess, 121.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 127.9ms
# Confidence ---> 0.93
# TV Monitor detected 171 times
# Confidence ---> 0.53
# Confidence ---> 0.27
# Speed: 2.0ms preprocess, 127.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 130.1ms
# Confidence ---> 0.93
# TV Monitor detected 172 times
# Confidence ---> 0.39
# Speed: 3.0ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 microwave, 1 clock, 146.9ms
# Confidence ---> 0.93
# TV Monitor detected 173 times
# Confidence ---> 0.39
# Confidence ---> 0.34
# Speed: 3.0ms preprocess, 146.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 144.5ms
# Confidence ---> 0.92
# TV Monitor detected 174 times
# Confidence ---> 0.52
# Confidence ---> 0.34
# Speed: 5.4ms preprocess, 144.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 151.6ms
# Confidence ---> 0.93
# TV Monitor detected 175 times
# Confidence ---> 0.43
# Confidence ---> 0.27
# Speed: 3.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 147.9ms
# Confidence ---> 0.9
# TV Monitor detected 176 times
# Confidence ---> 0.56
# Confidence ---> 0.45
# Speed: 2.0ms preprocess, 147.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 144.7ms
# Confidence ---> 0.92
# TV Monitor detected 177 times
# Confidence ---> 0.61
# Confidence ---> 0.6
# Speed: 2.0ms preprocess, 144.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 140.2ms
# Confidence ---> 0.91
# TV Monitor detected 178 times
# Confidence ---> 0.65
# Confidence ---> 0.52
# Speed: 3.0ms preprocess, 140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 128.0ms
# Confidence ---> 0.89
# TV Monitor detected 179 times
# Confidence ---> 0.53
# Confidence ---> 0.33
# Speed: 4.0ms preprocess, 128.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 146.1ms
# Confidence ---> 0.9
# TV Monitor detected 180 times
# Confidence ---> 0.51
# Confidence ---> 0.5
# Speed: 3.0ms preprocess, 146.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 132.8ms
# Confidence ---> 0.9
# TV Monitor detected 181 times
# Confidence ---> 0.5
# Confidence ---> 0.3
# Speed: 2.0ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 122.6ms
# Confidence ---> 0.9
# TV Monitor detected 182 times
# Confidence ---> 0.36
# Confidence ---> 0.28
# Speed: 2.0ms preprocess, 122.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 127.8ms
# Confidence ---> 0.9
# TV Monitor detected 183 times
# Confidence ---> 0.55
# Confidence ---> 0.54
# Speed: 3.0ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 125.1ms
# Confidence ---> 0.91
# TV Monitor detected 184 times
# Confidence ---> 0.58
# Confidence ---> 0.3
# Speed: 2.0ms preprocess, 125.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 136.2ms
# Confidence ---> 0.91
# TV Monitor detected 185 times
# Confidence ---> 0.45
# Confidence ---> 0.4
# Speed: 3.0ms preprocess, 136.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 141.7ms
# Confidence ---> 0.92
# TV Monitor detected 186 times
# Confidence ---> 0.49
# Confidence ---> 0.28
# Speed: 2.0ms preprocess, 141.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 170.6ms
# Confidence ---> 0.92
# TV Monitor detected 187 times
# Confidence ---> 0.63
# Confidence ---> 0.52
# Speed: 4.0ms preprocess, 170.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 174.9ms
# Confidence ---> 0.91
# TV Monitor detected 188 times
# Confidence ---> 0.6
# Confidence ---> 0.49
# Speed: 3.0ms preprocess, 174.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 142.4ms
# Confidence ---> 0.91
# TV Monitor detected 189 times
# Confidence ---> 0.47
# Confidence ---> 0.44
# Speed: 3.0ms preprocess, 142.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 139.7ms
# Confidence ---> 0.91
# TV Monitor detected 190 times
# Confidence ---> 0.44
# Confidence ---> 0.39
# Confidence ---> 0.32
# Speed: 4.0ms preprocess, 139.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 170.1ms
# Confidence ---> 0.92
# TV Monitor detected 191 times
# Confidence ---> 0.52
# Confidence ---> 0.4
# Speed: 3.0ms preprocess, 170.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 cell phone, 164.1ms
# Confidence ---> 0.9
# TV Monitor detected 192 times
# Confidence ---> 0.5
# Confidence ---> 0.41
# Speed: 3.0ms preprocess, 164.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 125.1ms
# Confidence ---> 0.92
# TV Monitor detected 193 times
# Confidence ---> 0.32
# Confidence ---> 0.29
# Speed: 3.0ms preprocess, 125.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Confidence ---> 0.92
# TV Monitor detected 194 times
# Speed: 2.0ms preprocess, 124.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.8ms
# Confidence ---> 0.93
# TV Monitor detected 195 times
# Speed: 3.0ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.8ms
# Confidence ---> 0.93
# TV Monitor detected 196 times
# Speed: 2.0ms preprocess, 125.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 133.4ms
# Confidence ---> 0.92
# TV Monitor detected 197 times
# Confidence ---> 0.27
# Speed: 2.0ms preprocess, 133.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 cell phone, 133.3ms
# Confidence ---> 0.93
# TV Monitor detected 198 times
# Confidence ---> 0.34
# Confidence ---> 0.33
# Confidence ---> 0.28
# Speed: 2.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 cell phone, 149.6ms
# Confidence ---> 0.91
# TV Monitor detected 199 times
# Confidence ---> 0.64
# Confidence ---> 0.27
# Speed: 4.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 152.9ms
# Confidence ---> 0.93
# TV Monitor detected 200 times
# Confidence ---> 0.38
# Speed: 3.0ms preprocess, 152.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 cell phone, 148.6ms
# Confidence ---> 0.92
# TV Monitor detected 201 times
# Confidence ---> 0.5
# Confidence ---> 0.47
# Confidence ---> 0.39
# Confidence ---> 0.32
# Speed: 3.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 cell phone, 147.6ms
# Confidence ---> 0.93
# TV Monitor detected 202 times
# Confidence ---> 0.29
# Confidence ---> 0.26
# Speed: 3.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 145.3ms
# Confidence ---> 0.92
# TV Monitor detected 203 times
# Confidence ---> 0.71
# Confidence ---> 0.3
# Speed: 3.0ms preprocess, 145.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 138.5ms
# Confidence ---> 0.92
# TV Monitor detected 204 times
# Confidence ---> 0.51
# Confidence ---> 0.26
# Confidence ---> 0.26
# Speed: 3.0ms preprocess, 138.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 148.0ms
# Confidence ---> 0.93
# TV Monitor detected 205 times
# Confidence ---> 0.7
# Confidence ---> 0.29
# Speed: 2.0ms preprocess, 148.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 126.2ms
# Confidence ---> 0.93
# TV Monitor detected 206 times
# Confidence ---> 0.59
# Confidence ---> 0.27
# Speed: 4.0ms preprocess, 126.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 tvs, 1 clock, 122.5ms
# Confidence ---> 0.92
# TV Monitor detected 207 times
# Confidence ---> 0.63
# Confidence ---> 0.41
# Confidence ---> 0.38
# TV Monitor detected 208 times
# Confidence ---> 0.32
# Speed: 3.0ms preprocess, 122.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 tvs, 134.6ms
# Confidence ---> 0.92
# TV Monitor detected 209 times
# Confidence ---> 0.4
# TV Monitor detected 210 times
# ...
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 184.6ms
# Confidence ---> 0.93
# TV Monitor detected 2443 times
# Confidence ---> 0.57
# Confidence ---> 0.44
# Confidence ---> 0.28
# Speed: 0.8ms preprocess, 184.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 205.0ms
# Confidence ---> 0.93
# TV Monitor detected 2444 times
# Confidence ---> 0.51
# Confidence ---> 0.41
# Confidence ---> 0.31
# Speed: 7.0ms preprocess, 205.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 189.1ms
# Confidence ---> 0.93
# TV Monitor detected 2445 times
# Confidence ---> 0.41
# Confidence ---> 0.38
# Speed: 3.0ms preprocess, 189.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 162.5ms
# Confidence ---> 0.93
# TV Monitor detected 2446 times
# Confidence ---> 0.64
# Confidence ---> 0.57
# Confidence ---> 0.34
# Speed: 4.0ms preprocess, 162.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 clock, 175.7ms
# Confidence ---> 0.92
# TV Monitor detected 2447 times
# Confidence ---> 0.43
# Confidence ---> 0.41
# Confidence ---> 0.32
# Confidence ---> 0.31
# Speed: 6.0ms preprocess, 175.7ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 clock, 269.2ms
# Confidence ---> 0.91
# TV Monitor detected 2448 times
# Confidence ---> 0.52
# Confidence ---> 0.44
# Confidence ---> 0.34
# Confidence ---> 0.27
# Speed: 2.0ms preprocess, 269.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 148.0ms
# Confidence ---> 0.91
# TV Monitor detected 2449 times
# Confidence ---> 0.5
# Confidence ---> 0.49
# Confidence ---> 0.27
# Speed: 3.6ms preprocess, 148.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 155.3ms
# Confidence ---> 0.92
# TV Monitor detected 2450 times
# Confidence ---> 0.44
# Confidence ---> 0.34
# Speed: 3.0ms preprocess, 155.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 141.1ms
# Confidence ---> 0.93
# TV Monitor detected 2451 times
# Confidence ---> 0.47
# Confidence ---> 0.33
# Confidence ---> 0.27
# Speed: 2.0ms preprocess, 141.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 clock, 178.6ms
# Confidence ---> 0.93
# TV Monitor detected 2452 times
# Confidence ---> 0.51
# Confidence ---> 0.45
# Confidence ---> 0.41
# Confidence ---> 0.3
# Speed: 5.2ms preprocess, 178.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 263.9ms
# Confidence ---> 0.92
# TV Monitor detected 2453 times
# Confidence ---> 0.38
# Confidence ---> 0.37
# Speed: 0.0ms preprocess, 263.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 155.2ms
# Confidence ---> 0.93
# TV Monitor detected 2454 times
# Confidence ---> 0.44
# Confidence ---> 0.42
# Speed: 3.0ms preprocess, 155.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 clock, 286.2ms
# Confidence ---> 0.93
# TV Monitor detected 2455 times
# Confidence ---> 0.52
# Confidence ---> 0.4
# Confidence ---> 0.35
# Confidence ---> 0.28
# Speed: 0.5ms preprocess, 286.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 196.6ms
# Confidence ---> 0.92
# TV Monitor detected 2456 times
# Confidence ---> 0.5
# Confidence ---> 0.43
# Confidence ---> 0.36
# Speed: 3.0ms preprocess, 196.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 283.3ms
# Confidence ---> 0.92
# TV Monitor detected 2457 times
# Confidence ---> 0.47
# Confidence ---> 0.46
# Confidence ---> 0.38
# Speed: 2.0ms preprocess, 283.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 174.9ms
# Confidence ---> 0.91
# TV Monitor detected 2458 times
# Confidence ---> 0.63
# Confidence ---> 0.42
# Confidence ---> 0.4
# Speed: 0.0ms preprocess, 174.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 168.4ms
# Confidence ---> 0.92
# TV Monitor detected 2459 times
# Confidence ---> 0.45
# Confidence ---> 0.36
# Confidence ---> 0.36
# Speed: 1.0ms preprocess, 168.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 168.4ms
# Confidence ---> 0.92
# TV Monitor detected 2460 times
# Confidence ---> 0.43
# Confidence ---> 0.29
# Confidence ---> 0.28
# Speed: 0.0ms preprocess, 168.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 153.3ms
# Confidence ---> 0.92
# TV Monitor detected 2461 times
# Confidence ---> 0.51
# Confidence ---> 0.5
# Confidence ---> 0.37
# Speed: 0.0ms preprocess, 153.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 1 clock, 329.8ms
# Confidence ---> 0.92
# TV Monitor detected 2462 times
# Confidence ---> 0.54
# Confidence ---> 0.44
# Confidence ---> 0.33
# Confidence ---> 0.29
# Speed: 0.0ms preprocess, 329.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 kite, 2 tvs, 1 clock, 169.6ms
# Confidence ---> 0.92
# TV Monitor detected 2463 times
# Confidence ---> 0.55
# Confidence ---> 0.43
# Confidence ---> 0.26
# Confidence ---> 0.26
# Speed: 1.0ms preprocess, 169.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 166.8ms
# Confidence ---> 0.91
# TV Monitor detected 2464 times
# Confidence ---> 0.5
# Confidence ---> 0.5
# Speed: 0.0ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 192.7ms
# Confidence ---> 0.92
# TV Monitor detected 2465 times
# Confidence ---> 0.57
# Confidence ---> 0.44
# Confidence ---> 0.44
# Speed: 1.0ms preprocess, 192.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 166.2ms
# Confidence ---> 0.92
# TV Monitor detected 2466 times
# Confidence ---> 0.35
# Confidence ---> 0.33
# Confidence ---> 0.3
# Speed: 4.0ms preprocess, 166.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 282.4ms
# Confidence ---> 0.92
# TV Monitor detected 2467 times
# Confidence ---> 0.58
# Confidence ---> 0.49
# Confidence ---> 0.28
# Speed: 3.0ms preprocess, 282.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 153.8ms
# Confidence ---> 0.92
# TV Monitor detected 2468 times
# Confidence ---> 0.58
# Confidence ---> 0.35
# Speed: 0.0ms preprocess, 153.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 clock, 149.2ms
# Confidence ---> 0.92
# TV Monitor detected 2469 times
# Confidence ---> 0.56
# Speed: 1.0ms preprocess, 149.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 150.5ms
# Confidence ---> 0.92
# TV Monitor detected 2470 times
# Confidence ---> 0.52
# Confidence ---> 0.49
# Confidence ---> 0.36
# Speed: 0.0ms preprocess, 150.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 167.3ms
# Confidence ---> 0.92
# TV Monitor detected 2471 times
# Confidence ---> 0.46
# Confidence ---> 0.46
# Confidence ---> 0.42
# Speed: 2.7ms preprocess, 167.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 261.3ms
# Confidence ---> 0.92
# TV Monitor detected 2472 times
# Confidence ---> 0.36
# Confidence ---> 0.33
# Confidence ---> 0.32
# Speed: 1.1ms preprocess, 261.3ms inference, 16.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 198.9ms
# Confidence ---> 0.92
# TV Monitor detected 2473 times
# Confidence ---> 0.5
# Confidence ---> 0.39
# Confidence ---> 0.33
# Speed: 1.0ms preprocess, 198.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 217.6ms
# Confidence ---> 0.92
# TV Monitor detected 2474 times
# Confidence ---> 0.56
# Confidence ---> 0.44
# Confidence ---> 0.3
# Speed: 4.7ms preprocess, 217.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 194.9ms
# Confidence ---> 0.91
# TV Monitor detected 2475 times
# Confidence ---> 0.57
# Confidence ---> 0.31
# Confidence ---> 0.29
# Speed: 2.8ms preprocess, 194.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 139.0ms
# Confidence ---> 0.91
# TV Monitor detected 2476 times
# Confidence ---> 0.52
# Confidence ---> 0.44
# Speed: 0.0ms preprocess, 139.0ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 kite, 2 tvs, 1 clock, 161.4ms
# Confidence ---> 0.91
# TV Monitor detected 2477 times
# Confidence ---> 0.61
# Confidence ---> 0.48
# Confidence ---> 0.39
# Confidence ---> 0.37
# Speed: 1.0ms preprocess, 161.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 186.9ms
# Confidence ---> 0.92
# TV Monitor detected 2478 times
# Confidence ---> 0.53
# Confidence ---> 0.42
# Confidence ---> 0.39
# Speed: 0.0ms preprocess, 186.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 252.7ms
# Confidence ---> 0.92
# TV Monitor detected 2479 times
# Confidence ---> 0.48
# Confidence ---> 0.46
# Speed: 2.7ms preprocess, 252.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 145.7ms
# Confidence ---> 0.92
# TV Monitor detected 2480 times
# Confidence ---> 0.55
# Confidence ---> 0.44
# Confidence ---> 0.34
# Speed: 0.0ms preprocess, 145.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 163.5ms
# Confidence ---> 0.91
# TV Monitor detected 2481 times
# Confidence ---> 0.44
# Confidence ---> 0.39
# Confidence ---> 0.32
# Speed: 0.0ms preprocess, 163.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 167.4ms
# Confidence ---> 0.91
# TV Monitor detected 2482 times
# Confidence ---> 0.49
# Confidence ---> 0.47
# Confidence ---> 0.41
# Speed: 0.0ms preprocess, 167.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 163.0ms
# Confidence ---> 0.92
# TV Monitor detected 2483 times
# Confidence ---> 0.45
# Confidence ---> 0.3
# Confidence ---> 0.26
# Speed: 0.0ms preprocess, 163.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 kite, 3 tvs, 1 clock, 602.8ms
# Confidence ---> 0.92
# TV Monitor detected 2484 times
# Confidence ---> 0.45
# Confidence ---> 0.43
# Confidence ---> 0.41
# Confidence ---> 0.38
# Confidence ---> 0.27
# Speed: 0.0ms preprocess, 602.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 669.3ms
# Confidence ---> 0.91
# TV Monitor detected 2485 times
# Confidence ---> 0.55
# Confidence ---> 0.51
# Confidence ---> 0.38
# Speed: 0.0ms preprocess, 669.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 161.9ms
# Confidence ---> 0.92
# TV Monitor detected 2486 times
# Confidence ---> 0.51
# Confidence ---> 0.36
# Confidence ---> 0.26
# Speed: 12.8ms preprocess, 161.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 176.9ms
# Confidence ---> 0.91
# TV Monitor detected 2487 times
# Confidence ---> 0.57
# Confidence ---> 0.5
# Confidence ---> 0.29
# Speed: 4.0ms preprocess, 176.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 189.4ms
# Confidence ---> 0.91
# TV Monitor detected 2488 times
# Confidence ---> 0.48
# Confidence ---> 0.45
# Confidence ---> 0.36
# Speed: 3.4ms preprocess, 189.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 225.4ms
# Confidence ---> 0.92
# TV Monitor detected 2489 times
# Confidence ---> 0.6
# Confidence ---> 0.48
# Speed: 49.6ms preprocess, 225.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 clock, 159.7ms
# Confidence ---> 0.92
# TV Monitor detected 2490 times
# Confidence ---> 0.54
# Confidence ---> 0.49
# Speed: 5.0ms preprocess, 159.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 152.2ms
# Confidence ---> 0.91
# TV Monitor detected 2491 times
# Confidence ---> 0.49
# Confidence ---> 0.47
# Confidence ---> 0.28
# Speed: 14.7ms preprocess, 152.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 160.2ms
# Confidence ---> 0.92
# TV Monitor detected 2492 times
# Confidence ---> 0.57
# Confidence ---> 0.39
# Confidence ---> 0.39
# Speed: 0.0ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 166.8ms
# Confidence ---> 0.91
# TV Monitor detected 2493 times
# Confidence ---> 0.44
# Confidence ---> 0.3
# Confidence ---> 0.27
# Speed: 0.0ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 253.0ms
# Confidence ---> 0.92
# TV Monitor detected 2494 times
# Confidence ---> 0.49
# Confidence ---> 0.33
# Confidence ---> 0.29
# Speed: 0.0ms preprocess, 253.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 166.2ms
# Confidence ---> 0.92
# TV Monitor detected 2495 times
# Confidence ---> 0.45
# Confidence ---> 0.44
# Confidence ---> 0.42
# Speed: 0.0ms preprocess, 166.2ms inference, 16.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 149.3ms
# Confidence ---> 0.92
# TV Monitor detected 2496 times
# Confidence ---> 0.6
# Confidence ---> 0.59
# Confidence ---> 0.39
# Speed: 0.0ms preprocess, 149.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 150.3ms
# Confidence ---> 0.92
# TV Monitor detected 2497 times
# Confidence ---> 0.55
# Confidence ---> 0.47
# Confidence ---> 0.41
# Speed: 1.1ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 184.4ms
# Confidence ---> 0.92
# TV Monitor detected 2498 times
# Confidence ---> 0.55
# Confidence ---> 0.47
# Confidence ---> 0.32
# Speed: 0.0ms preprocess, 184.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 266.9ms
# Confidence ---> 0.92
# TV Monitor detected 2499 times
# Confidence ---> 0.56
# Confidence ---> 0.37
# Confidence ---> 0.26
# Speed: 0.0ms preprocess, 266.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 249.9ms
# Confidence ---> 0.92
# TV Monitor detected 2500 times
# Confidence ---> 0.56
# Confidence ---> 0.43
# Confidence ---> 0.4
# Speed: 1.0ms preprocess, 249.9ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 159.0ms
# Confidence ---> 0.92
# TV Monitor detected 2501 times
# Confidence ---> 0.52
# Confidence ---> 0.52
# Confidence ---> 0.44
# Speed: 41.6ms preprocess, 159.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 165.1ms
# Confidence ---> 0.92
# TV Monitor detected 2502 times
# Confidence ---> 0.49
# Confidence ---> 0.41
# Confidence ---> 0.34
# Speed: 0.0ms preprocess, 165.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 166.0ms
# Confidence ---> 0.92
# TV Monitor detected 2503 times
# Confidence ---> 0.54
# Confidence ---> 0.44
# Confidence ---> 0.39
# Speed: 0.0ms preprocess, 166.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 clock, 136.7ms
# Confidence ---> 0.92
# TV Monitor detected 2504 times
# Confidence ---> 0.47
# Confidence ---> 0.44
# Confidence ---> 0.3
# Speed: 0.0ms preprocess, 136.7ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# **Tarea: Aplicación de detección de objetos específicos con YOLO**
#
# Objetivo: Investiga cómo modificar el script de detección de objetos en tiempo real con YOLO para que solo detecte ciertas clases de objetos. Luego, darle una aplicación específica a esta detección.
#
# Instrucciones:
#
# 1. Elija un subconjunto de las 80 clases disponibles en YOLO que sean relevantes para una aplicación específica. Por ejemplo, si está creando una aplicación para ayudar a los conductores a detectar peatones y vehículos, podría elegir las clases 'persona', 'bicicleta', 'coche', 'moto', 'autobús' y 'camión'.
#
# 2. Modifique el script de detección de objetos en tiempo real para que solo detecte las clases que ha seleccionado. Para hacer esto, necesitará crear una lista de los índices de las clases que ha selecciono y luego agregar una condición en el bucle donde se procesan los resultados de la detección para solo procesar las detecciones que corresponden a las clases seleccionadas.
#
# 3. Pruebe su script modificado para asegurarse de que solo está detectando las clases que ha seleccionado.
#
# 4. Piense en una aplicación específica para su detección de objetos. ¿Cómo podría usar la información de las detecciones para ayudar al usuario? Por ejemplo, en la aplicación para conductores, podría alertar al usuario si detecta un peatón o un vehículo en una zona de peligro.
#
# 5. En clase, presente las clases que seleccionó, cómo modificó el script de detección de objetos, los resultados de sus pruebas, la aplicación específica que ha ideado para su detección de objetos, y cómo la aplicación serviría al usuario final u organización.
